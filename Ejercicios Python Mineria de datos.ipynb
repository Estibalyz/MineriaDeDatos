# %% [markdown]
# # Equipo 10
#
# Grupo 003, Viernes 6-9
#
# - 1803561   López Peña Marcelo Adrián
# - 1809399   Villarreal Martínez Estibalyz
# - 1863305   Zuñiga Cedillo Milton Humberto

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - Lectura de la base de datos

# %%
df_excel = pd.read_excel('C:/Users/Usuario/Desktop/FCFM/5 semestre/Mineria de datos/StudentsPerformance.xlsx')

# %% [markdown]
# ## P1 Manipulación de datos

# %%
df_excel.shape
# Out:
# (1000, 8)

# %% [markdown]
# Cantidad de filas y columnas

# %%
df_excel.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_excel.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df_excel.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df_excel.rename(columns = {'gender':'genero'})
# Out:
#      genero race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_excel.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df_excel['math score'].dtype
# Out:
# dtype('int64')

# %%
df_excel.math score.astype("float")
# Out:
#   File "<ipython-input-15-ca629d3bf626>", line 1
#     df_excel.math score.astype("float")
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# Para el siguiente avance debemos cambiar el nombre de nuestras columnas ya que el sistema no detecta los espacios

# %%
df_excel.lunch.unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
df_excel.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
df_excel.isnull().any()
# Out:
# gender                         False
# race/ethnicity                 False
# parental level of education    False
# lunch                          False
# test preparation course        False
# math score                     False
# reading score                  False
# writing score                  False
# dtype: bool

# %%
df_excel.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# ## P2 Visualización de datos

# %%
df_excel['math score'].describe()
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %%
df_excel['writing score'].describe()
# Out:
# count    1000.000000
# mean       68.054000
# std        15.195657
# min        10.000000
# 25%        57.750000
# 50%        69.000000
# 75%        79.000000
# max       100.000000
# Name: writing score, dtype: float64

# %%
df_excel['reading score'].describe()
# Out:
# count    1000.000000
# mean       69.169000
# std        14.600192
# min        17.000000
# 25%        59.000000
# 50%        70.000000
# 75%        79.000000
# max       100.000000
# Name: reading score, dtype: float64

# %%
df_excel['lunch'].describe()
# Out:
# count         1000
# unique           2
# top       standard
# freq           645
# Name: lunch, dtype: object

# %%
df_excel['gender'].describe()
# Out:
# count       1000
# unique         2
# top       female
# freq         518
# Name: gender, dtype: object

# %%
df_excel.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
df_excel.cov()
# Out:
#                math score  reading score  writing score
# math score     229.918998     180.998958     184.939133
# reading score  180.998958     213.165605     211.786661
# writing score  184.939133     211.786661     230.907992

# %%
df_excel.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df_excel['math score'].value_counts().plot.bar()

# %% [markdown]
# Debemos cambiar la cantidad de barras que queremos mostrar para aapreciarlas correctamenete

# %%
df_excel['math score'].value_counts().head(15).plot.bar()

# %% [markdown]
# Mostramos solo las 15 calificaciones que mas se repiten

# %%
df_excel['math score'].value_counts().sort_index().plot.bar()

# %% [markdown]
# Se muestra un conteo de las calificaciones el cual no se puede apreciar el eje x

# %%
df_excel['math score'].value_counts().head(15).sort_index().plot.bar()

# %% [markdown]
# Al igual que en el caso anterior tratamos de recortar la cantidad de barras que se muestra pero no nos sirve de mucho

# %%
df_excel['math score'].value_counts().sort_index().plot.line()

# %% [markdown]
# Para solucionar el problema anterior mostramos la grafica de frecuencias con lineas en lugar de barras

# %%
df_excel['math score'].value_counts().sort_index().plot.area()

# %% [markdown]
# Otra forma de mostrar la frecuencia de lineas es con areas

# %%
df_excel['math score'].plot.hist()

# %% [markdown]
# Con un histograma no se aprecia muy bien la tendencia que sigue la frecuencia

# %%
df_excel[df_excel['math score'] < 100].plot.hexbin(x='math score', y='writing score', gridsize = 15)

# %% [markdown]
# Nos muestra como se relacionan las calificaciones de matematicas y escritura

# %%
df_excel[df_excel['math score'] < 100].plot.hexbin(x='math score', y='reading score',  gridsize = 15)

# %% [markdown]
# Nos muestra como se relacionan las calificaciones de matematicas y lectura

# %%
df_excel[df_excel['reading score'] < 100].plot.hexbin(x='reading score', y='writing score',  gridsize = 15)

# %% [markdown]
# Nos muestra como se relacionan las calificaciones de lectura y escritura

# %%
df_excel.plot.bar(stacked=True)

# %% [markdown]
# Este tipo de grafica no se aprecia muy bien

# %%
df_excel.plot.area()

# %%
import seaborn as sns
sns.countplot(df_excel['math score'])
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.kdeplot(df_excel.query('math score < 70').math score)
# Out:
#   File "<ipython-input-61-3c376f1d5e38>", line 1
#     sns.kdeplot(df_excel.query('math score < 70').math score)
#                                                        ^
# SyntaxError: invalid syntax

# %%
df = df_excel[df_excel.gender.isin(df_excel.gender.value_counts().head(5).index)]

sns.boxplot(
    x='gender',
    y='math score',
    data=df
)

# %%
df = df_excel[df_excel.gender.isin(df_excel.gender.value_counts().head(5).index)]

sns.boxplot(
    x='lunch',
    y='math score',
    data=df
)

# %%
df = df_excel[df_excel.gender.isin(df_excel.gender.value_counts().head(5).index)]

sns.boxplot(
    x='parental level of education',
    y='math score',
    data=df
)

# %%
df_excel['parental level of education'].head()
# Out:
# 0     bachelor's degree
# 1          some college
# 2       master's degree
# 3    associate's degree
# 4          some college
# Name: parental level of education, dtype: object

# %%
sns.violinplot(
    x='gender',
    y='math score',
    data=df_excel[df_excel.gender.isin(df_excel.gender.value_counts()[:5].index)]
)

# %%
sns.violinplot(
    x='lunch',
    y='math score',
    data=df_excel[df_excel.lunch.isin(df_excel.lunch.value_counts()[:5].index)]
)

# %%
import pandas_profiling
sns.pairplot(df_excel[['math score', 'reading score', 'writing score']])

# %%
import matplotlib.pyplot as plt
f,ax=plt.subplots(figsize = (18,18))
sns.heatmap(df.corr(),annot= True,linewidths=0.5,fmt = ".1f",ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Mapa de correlación')
plt.savefig('graph.png')
plt.show()

# %%
sns.lmplot(x='math score', y='reading score', hue='writing score', 
           data=df_excel.loc[df_excel['diagnosis'].isin(['B', 'M'])], 
           fit_reg=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'diagnosis'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-643a1dee0aaf> in <module>
# ...
