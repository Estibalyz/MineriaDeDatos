# %%
import pandas as pd
import seaborn as sns
df_excel = pd.read_excel('C:/Users/Usuario/Desktop/FCFM/5 semestre/Mineria de datos/StudentsPerformance.xlsx')
df_mod = df_excel.drop('race/ethnicity',axis = 1 )
df_mod1 = df_mod.rename(columns = {'parental level of education':'parental_education'})
df_mod2 = df_mod1.rename(columns = {'test preparation course':'preparation'})
df_mod3 = df_mod2.rename(columns = {'math score':'math_score'})
df_mod4 = df_mod3.rename(columns = {'reading score':'reading_score'})
df = df_mod4.rename(columns = {'writing score':'writing_score'})
df['prom'] = round((df['math_score'] + df['reading_score'] + df['writing_score'])/3, 2)
df.head()
# Out:
#    gender parental_education         lunch preparation  math_score  \
# 0  female         bachelor's      standard        none          72
# 1  female       some college      standard   completed          69
# 2  female           master's      standard        none          90
# 3    male       associate's   free/reduced        none          47
# 4    male       some college      standard        none          76
#
#    reading_score  writing_score   prom
# 0             72             74  72.67
# 1             90             88  82.33
# 2             95             93  92.67
# 3             57             44  49.33
# 4             78             75  76.33

# %%
sns.pairplot(df[['prom']])

# %%
df.boxplot()

# %%
df.boxplot(['prom'])

# %%
sns.catplot(x = 'gender', y = 'prom', data = df, kind = "box", aspect = 1);

# %%
sns.catplot(x = 'parental_education', y = 'prom', data = df, kind = "box", aspect = 2);

# %%
sns.catplot(x = 'parental_education', y = 'prom', data = df, kind = "box", hue = 'gender', aspect = 2);

# %%
sns.catplot(x = 'lunch', y = 'prom', data = df, kind = "box", aspect = 1);

# %%
sns.catplot(x = 'lunch', y = 'prom', data = df, kind = "box", hue = 'gender', aspect = 1);

# %%
sns.catplot(x = 'preparation', y = 'prom', data = df, kind = "box", aspect = 1);

# %%
sns.catplot(x = 'preparation', y = 'prom', data = df, kind = "box", hue = 'gender', aspect = 1);

# %%
df
# Out:
#      gender parental_education         lunch preparation  math_score  \
# 0    female         bachelor's      standard        none          72
# 1    female       some college      standard   completed          69
# 2    female           master's      standard        none          90
# 3      male       associate's   free/reduced        none          47
# 4      male       some college      standard        none          76
# ..      ...                ...           ...         ...         ...
# 995  female           master's      standard   completed          88
# 996    male        high school  free/reduced        none          62
# 997  female        high school  free/reduced   completed          59
# 998  female       some college      standard   completed          68
# 999  female       some college  free/reduced        none          77
#
#      reading_score  writing_score   prom
# 0               72             74  72.67
# 1               90             88  82.33
# ...

# %%
sns.catplot(x = 'parental_education', y = 'prom', data = df, kind = "box", hue = 'lunch', aspect = 2);

# %%
sns.catplot(x = 'lunch', y = 'prom', data = df, kind = "box", hue = 'parental_education', aspect = 2);
